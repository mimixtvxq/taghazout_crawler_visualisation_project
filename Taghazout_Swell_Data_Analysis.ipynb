# %% [markdown]
# # Taghazout Swell Data Analysis

# %%
# Read CSV File 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

filename = 'taghazout_surf_data.csv'

df = pd.read_csv(filename, parse_dates = True)

print df.columns
# Out:
# Index([u'date', u'swell_height_ft', u'swell_period_secs', u'wind_speed_mph',
#        u'swell_dir', u'wind_dir'],
#       dtype='object')

# %%
#convert date into datetime format
from datetime import datetime
import matplotlib.dates as mdates
dates = df["date"]
#type(dates)
#print dates
df["times"] = [datetime.strptime(d, '%Y/%d/%m') for d in dates]

# %%
#extract years
df["year"] = pd.DatetimeIndex(df["times"]).year
df["month"] = pd.DatetimeIndex(df["times"]).month

print df.head()
# Out:
#        date  swell_height_ft  swell_period_secs  wind_speed_mph  swell_dir  \
# 0  2007/1/1              8.4                 13               4        310
# 1  2006/1/1              6.5                 13              13        300
# 2  2005/1/1              6.0                 14               7        315
# 3  2004/1/1              7.4                  6              25          5
# 4  2003/1/1             10.4                 14               2        300
#
#    wind_dir      times  year  month
# 0       235 2007-01-01  2007      1
# 1        10 2006-01-01  2006      1
# 2       235 2005-01-01  2005      1
# 3        25 2004-01-01  2004      1
# 4       305 2003-01-01  2003      1

# %%
#convert feet to metres and attach it to df
swell_height = []
for i in range(0,len(df["date"])):
    swell_height.append(df["swell_height_ft"][i]*0.3048)
#print swell_height

#attach conversion to df
df["swell_height"] = swell_height

print df.head()
# Out:
#        date  swell_height_ft  swell_period_secs  wind_speed_mph  swell_dir  \
# 0  2007/1/1              8.4                 13               4        310
# 1  2006/1/1              6.5                 13              13        300
# 2  2005/1/1              6.0                 14               7        315
# 3  2004/1/1              7.4                  6              25          5
# 4  2003/1/1             10.4                 14               2        300
#
#    wind_dir      times  year  month  swell_height
# 0       235 2007-01-01  2007      1       2.56032
# 1        10 2006-01-01  2006      1       1.98120
# 2       235 2005-01-01  2005      1       1.82880
# 3        25 2004-01-01  2004      1       2.25552
# 4       305 2003-01-01  2003      1       3.16992

# %%
#create separate df for each year
#type(df['year'])
df_2007 = df.loc[df['year'] == 2007]
df_2006 = df.loc[df['year'] == 2006]
df_2005 = df.loc[df['year'] == 2005]
df_2004 = df.loc[df['year'] == 2004]
df_2003 = df.loc[df['year'] == 2003]
df_2002 = df.loc[df['year'] == 2002]
df_2001 = df.loc[df['year'] == 2001]
df_2000 = df.loc[df['year'] == 2000]
df_2000 = df_2000.drop_duplicates()
df_1999 = df.loc[df['year'] == 1999]
df_1998 = df.loc[df['year'] == 1998]
df_1998 = df_1998.drop_duplicates()
df_1997 = df.loc[df['year'] == 1997]
df_1997 = df_1997.drop_duplicates()

print df_1999
# Out:
#             date  swell_height_ft  swell_period_secs  wind_speed_mph  \
# 8       1999/1/1             16.4                 12               9
# 23      1999/2/1             14.2                 13               7
# 38      1999/3/1             10.5                 13               4
# 53      1999/4/1             11.8                 14               9
# 68      1999/5/1              8.5                 14              13
# 83      1999/6/1             10.5                 14              20
# 98      1999/7/1             10.3                 13              13
# 113     1999/8/1              7.4                 12              11
# 128     1999/9/1              5.5                 11              16
# 143    1999/10/1              8.0                 12              22
# 158    1999/11/1              9.8                 11               9
# 173    1999/12/1             15.0                 13               2
# 188    1999/13/1             11.3                 13               7
# ...

# %%
print df_2001
# Out:
#             date  swell_height_ft  swell_period_secs  wind_speed_mph  \
# 6       2001/1/1              7.2                 13              11
# 21      2001/2/1             18.1                 17               2
# 36      2001/3/1             15.5                 14               2
# 51      2001/4/1             10.2                 13               7
# 66      2001/5/1              9.1                 13              11
# 81      2001/6/1             10.7                 13              18
# 96      2001/7/1             10.5                 12              16
# 111     2001/8/1              7.9                 11               9
# 126     2001/9/1              5.7                 11              20
# 141    2001/10/1              6.7                 10              20
# 156    2001/11/1              5.9                  9              18
# 171    2001/12/1             13.1                 11              18
# 186    2001/13/1             11.9                 11              18
# ...

# %%
#create index for each year
df_1997['day_of_year'] = np.arange(len(df_1997))
df_1998['day_of_year'] = np.arange(len(df_1998))
df_1999['day_of_year'] = np.arange(len(df_1999))
df_2000['day_of_year'] = np.arange(len(df_2000))
df_2001['day_of_year'] = np.arange(len(df_2001))
df_2002['day_of_year'] = np.arange(len(df_2002))
df_2003['day_of_year'] = np.arange(len(df_2003))
df_2004['day_of_year'] = np.arange(len(df_2004))
df_2005['day_of_year'] = np.arange(len(df_2005))
df_2006['day_of_year'] = np.arange(len(df_2006))
df_2007['day_of_year'] = np.arange(len(df_2007))

#print df_2006.head()
#print len(df_2006)
# Out:
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#step function fit - clear monthly average view
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline

plt.figure(figsize=(10,40)) 
#plt.xticks(np.arange(0,365,30), rotation=20)


x1=plt.subplot(10,1,10)
x2=plt.subplot(10,1,9)
x3=plt.subplot(10,1,8)
x4=plt.subplot(10,1,7)
x5=plt.subplot(10,1,6)
x6=plt.subplot(10,1,5)
x7=plt.subplot(10,1,4)
x8=plt.subplot(10,1,3)
x9=plt.subplot(10,1,2)
x10=plt.subplot(10,1,1)


#create a spline function with 12 knots -- approx monthly cutoff = natural cutpoint
#2006
s_2006 = UnivariateSpline(df_2006['day_of_year'],df_2006['swell_height'])
xs_2006 = np.linspace(0,365,13)
ys_2006 = s_2006(xs_2006)

#2005
s_2005 = UnivariateSpline(df_2005['day_of_year'],df_2005['swell_height'])
xs_2005 = np.linspace(0,365,13)
ys_2005 = s_2005(xs_2005)

#2004
s_2004 = UnivariateSpline(df_2004['day_of_year'],df_2004['swell_height'])
xs_2004 = np.linspace(0,365,13)
ys_2004 = s_2004(xs_2004)

#2003
s_2003 = UnivariateSpline(df_2003['day_of_year'],df_2003['swell_height'])
xs_2003 = np.linspace(1,365,13)
ys_2003 = s_2003(xs_2003)

#2002
s_2002 = UnivariateSpline(df_2002['day_of_year'],df_2002['swell_height'])
xs_2002 = np.linspace(1,365,13)
ys_2002 = s_2002(xs_2002)

#2001
s_2001 = UnivariateSpline(df_2001['day_of_year'],df_2001['swell_height'])
xs_2001 = np.linspace(1,365,13)
ys_2001 = s_2001(xs_2001)

#2000
s_2000 = UnivariateSpline(df_2000['day_of_year'],df_2000['swell_height'])
xs_2000 = np.linspace(1,365,13)
ys_2000 = s_2000(xs_2000)

#1999
s_1999 = UnivariateSpline(df_1999['day_of_year'],df_1999['swell_height'])
xs_1999 = np.linspace(1,365,13)
ys_1999 = s_1999(xs_1999)
#1999 Swell Period
s2_1999 = UnivariateSpline(df_1999['day_of_year'],df_1999['swell_period_secs'])
y2s_1999 = s2_1999(xs_1999)

#1998
s_1998 = UnivariateSpline(df_1998['day_of_year'],df_1998['swell_height'])
xs_1998 = np.linspace(1,365,13)
ys_1998 = s_1998(xs_1998)

#1997
s_1997 = UnivariateSpline(df_1997['day_of_year'],df_1997['swell_height'])
xs_1997 = np.linspace(1,365,13)
ys_1997 = s_1997(xs_1997)

# Plot step functions to find trends of low season periods 
x10.step(xs_2006,ys_2006, label = "2006") #color="#000000")
x9.step(xs_2005,ys_2005, label = "2005") #color = "#000000")
x8.step(xs_2004,ys_2004, label = "2004") #color = "#000000")
x7.step(xs_2003,ys_2003, label = "2003") #color = "#0e2c5e")
x6.step(xs_2002,ys_2002, label = "2002") #color = "#1449a0")
x5.step(xs_2001,ys_2001, label = "2001") #color = "#3061b2")
x4.step(xs_2000,ys_2000, label = "2000") #color = "#5889d8")
x3.step(xs_1999,ys_1999, label = "1999") #color = "#7ea5e5")
x2.step(xs_1998,ys_1998, label = "1998") #color = "#b4c7e8")
x1.step(xs_1997,ys_1997, label = "1997") #color =  "#dce6f7") 

#cosmetic labelling of axis and legend display
ticks = [a for a in range(365) if (a-16)%30 == 0]
print ticks
plt.setp(x10, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x9, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x8, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x7, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x6, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x5, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x4, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x3, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x2, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x1, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")

x1.set_title("1997")
x2.set_title("1998")
x3.set_title("1999")
x4.set_title("2000")
x5.set_title("2001")
x6.set_title("2002")
x7.set_title("2003")
x8.set_title("2004")
x9.set_title("2005")
x10.set_title("2006")


x10.legend(loc = 'best')
x9.legend(loc = 'best')
x8.legend(loc = 'best')
x7.legend(loc = 'best')
x6.legend(loc = 'best')
x5.legend(loc = 'best')
x4.legend(loc = 'best')
x3.legend(loc = 'best')
x2.legend(loc = 'best')
x1.legend(loc = 'best')

x2.grid(color='gray', linestyle='-', linewidth=0.5)
x3.grid(color='gray', linestyle='-', linewidth=0.5)
x4.grid(color='gray', linestyle='-', linewidth=0.5)
x5.grid(color='gray', linestyle='-', linewidth=0.5)
x6.grid(color='gray', linestyle='-', linewidth=0.5)
x7.grid(color='gray', linestyle='-', linewidth=0.5)
x8.grid(color='gray', linestyle='-', linewidth=0.5)
x9.grid(color='gray', linestyle='-', linewidth=0.5)
x10.grid(color='gray', linestyle='-', linewidth=0.5)
x1.grid(color='gray', linestyle='-', linewidth=0.5)

plt.title("Taghazout Surf Seasons - Step Function", fontsize=20)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.5, hspace=0.7)
plt.show()
# Out:
# [16, 46, 76, 106, 136, 166, 196, 226, 256, 286, 316, 346]

# %%
#smooth spline fit
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline

plt.figure(figsize=(10,40))
#plt.xticks(np.arange(0,365,30), rotation=20)

x1=plt.subplot(10,1,1)
x2=plt.subplot(10,1,2)
x3=plt.subplot(10,1,3)
x4=plt.subplot(10,1,4)
x5=plt.subplot(10,1,5)
x6=plt.subplot(10,1,6)
x7=plt.subplot(10,1,7)
x8=plt.subplot(10,1,8)
x9=plt.subplot(10,1,9)
x10=plt.subplot(10,1,10)
#x1.plot(df_2006['day_of_year'],df_2006['swell_height_ft'],'o', label='2006')

#create a spline function with 12 knots -- approx monthly cutoff = natural cutpoint
#2006
s_2006 = UnivariateSpline(df_2006['day_of_year'],df_2006['swell_height'])
s_2006.set_smoothing_factor(1000)

#2005
s_2005 = UnivariateSpline(df_2005['day_of_year'],df_2005['swell_height'])
s_2005.set_smoothing_factor(1000)

#2004
s_2004 = UnivariateSpline(df_2004['day_of_year'],df_2004['swell_height'])
s_2004.set_smoothing_factor(1000)

#2003
s_2003 = UnivariateSpline(df_2003['day_of_year'],df_2003['swell_height'])
s_2003.set_smoothing_factor(1000)

#2002
s_2002 = UnivariateSpline(df_2002['day_of_year'],df_2002['swell_height'])
s_2002.set_smoothing_factor(1000)

#2001
s_2001 = UnivariateSpline(df_2001['day_of_year'],df_2001['swell_height'])
s_2001.set_smoothing_factor(1000)

#2000
s_2000 = UnivariateSpline(df_2000['day_of_year'],df_2000['swell_height'])
s_2000.set_smoothing_factor(1000)


#1999
s_1999 = UnivariateSpline(df_1999['day_of_year'],df_1999['swell_height'])
s_1999.set_smoothing_factor(1000)


#1998
s_1998 = UnivariateSpline(df_1998['day_of_year'],df_1998['swell_height'])
s_1998.set_smoothing_factor(1000)


#1997
s_1997 = UnivariateSpline(df_1997['day_of_year'],df_1997['swell_height'])
s_1997.set_smoothing_factor(1000)

'''
#Plot Original Points
x10.plot(df_1997['day_of_year'],df_1997['swell_height'],'x')
x9.plot(df_1998['day_of_year'],df_1998['swell_height'],'x')
x8.plot(df_1999['day_of_year'],df_1999['swell_height'],'x')
x7.plot(df_2000['day_of_year'],df_2000['swell_height'],'x')
x6.plot(df_2001['day_of_year'],df_2001['swell_height'],'x')
x5.plot(df_2002['day_of_year'],df_2002['swell_height'],'x')
x4.plot(df_2003['day_of_year'],df_2003['swell_height'],'x')
x3.plot(df_2004['day_of_year'],df_2004['swell_height'],'x')
x2.plot(df_2005['day_of_year'],df_2005['swell_height'],'x')
x1.plot(df_2006['day_of_year'],df_2006['swell_height'],'x')
'''

# Plot smoothing spline function functions to find trends of low season periods 
x10.plot(s_1997(np.arange(len(df_1997['day_of_year']))), label='1997 -Smooth 1000')
x9.plot(s_1998(np.arange(len(df_1998['day_of_year']))), label='1998 - Smooth 1000')
x8.plot(s_1999(np.arange(len(df_1999['day_of_year']))), label='1999 - Smooth 1000')
x7.plot(s_2000(np.arange(len(df_2000['day_of_year']))), label='2000 - Smooth 1000')
x6.plot(s_2001(np.arange(len(df_2001['day_of_year']))), label='2001 - Smooth 1000')
x5.plot(s_2002(np.arange(len(df_2002['day_of_year']))), label='2002 - Smooth 1000')
x4.plot(s_2003(np.arange(len(df_2003['day_of_year']))), label='2003 - Smooth 1000')
x3.plot(s_2004(np.arange(len(df_2004['day_of_year']))), label='2004 - Smooth 1000')
x2.plot(s_2005(np.arange(len(df_2005['day_of_year']))), label='2005 - Smooth 1000')
x1.plot(s_2006(np.arange(len(df_2006['day_of_year']))), label='2006 - Smooth 1000')

#cosmetic labelling of axis and legend display
ticks = [a for a in range(365) if (a-16)%30 == 0]
print ticks
plt.setp(x10, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x9, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x8, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x7, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x6, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x5, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x4, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x3, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x2, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")
plt.setp(x1, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")


#cosmetic labelling of axis and legend display

x1.set_title("Taghazout Surf Seasons - Smoothing Spline", fontsize=20)
x2.set_title("2005")
x3.set_title("2004")
x4.set_title("2003")
x5.set_title("2002")
x6.set_title("2001")
x7.set_title("2000")
x8.set_title("1999")
x9.set_title("1998")
x10.set_title("1997")

x10.legend(loc = 'best')
x9.legend(loc = 'best')
x8.legend(loc = 'best')
x7.legend(loc = 'best')
x6.legend(loc = 'best')
x5.legend(loc = 'best')
x4.legend(loc = 'best')
x3.legend(loc = 'best')
x2.legend(loc = 'best')
x1.legend(loc = 'best')

x1.grid(color='gray', linestyle='-', linewidth=0.5)
x2.grid(color='gray', linestyle='-', linewidth=0.5)
x3.grid(color='gray', linestyle='-', linewidth=0.5)
x4.grid(color='gray', linestyle='-', linewidth=0.5)
x5.grid(color='gray', linestyle='-', linewidth=0.5)
x6.grid(color='gray', linestyle='-', linewidth=0.5)
x7.grid(color='gray', linestyle='-', linewidth=0.5)
x8.grid(color='gray', linestyle='-', linewidth=0.5)
x9.grid(color='gray', linestyle='-', linewidth=0.5)
x10.grid(color='gray', linestyle='-', linewidth=0.5)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.5, hspace=0.6)
plt.show()
# Out:
# [16, 46, 76, 106, 136, 166, 196, 226, 256, 286, 316, 346]

# %%
#polynomial fit

plt.figure(figsize=(15,10))
ax=plt.subplot(111)

#plot for 1997
x1 = df_1997['day_of_year']
y1 = df_1997['swell_height']
z1 = np.polyfit(x1,y1, 4)
f1 = np.poly1d(z1)

print f1

x_new1997 = np.linspace(1,365,50)
y_new1997 = f1(x_new1997)

ax.plot(x_new1997,y_new1997,label="1997", color = "#dce6f7")

#plot for 1998
x2 = df_1998['day_of_year']
y2 = df_1998['swell_height']
z2 = np.polyfit(x2,y2, 4)
f2 = np.poly1d(z2)
print f2

x_new1998 = np.linspace(1,365,50)
y_new1998 = f2(x_new1998)

ax.plot(x_new1998,y_new1998,label="1998", color = "#b4c7e8")

#plot for 1999
x3 = df_1999['day_of_year']
y3 = df_1999['swell_height']
z3 = np.polyfit(x3,y3, 4)
f3 = np.poly1d(z3)
#ax.plot(x3,y3,'o', label='1999')
print f3

x_new1999 = np.linspace(1,365,50)
y_new1999 = f3(x_new1999)

ax.plot(x_new1999,y_new1999,label="1999", color = "#7ea5e5")

#plot for 2000
x4 = df_2000['day_of_year']
y4 = df_2000['swell_height']
z4 = np.polyfit(x4,y4, 4)
f4 = np.poly1d(z4)


x_new2000 = np.linspace(1,365,50)
y_new2000 = f4(x_new2000)

ax.plot(x_new2000,y_new2000,label="2000", color = "#5889d8")

#plot for 2001
x5 = df_2001['day_of_year']
y5 = df_2001['swell_height']
z5 = np.polyfit(x5,y5, 4)
f5 = np.poly1d(z5)


x_new2001 = np.linspace(1,365,50)
y_new2001 = f5(x_new2001)

ax.plot(x_new2001,y_new2001,label="2001", color = "#3061b2")

#plot for 2002
x6 = df_2002['day_of_year']
y6 = df_2002['swell_height']
z6 = np.polyfit(x6,y6, 4)
f6 = np.poly1d(z6)


x_new2002 = np.linspace(1,365,50)
y_new2002 = f6(x_new2002)

ax.plot(x_new2002,y_new2002,label="2002", color = "#1449a0")

#plot for 2003
x7 = df_2003['day_of_year']
y7 = df_2003['swell_height']
z7 = np.polyfit(x7,y7, 4)
f7 = np.poly1d(z7)


x_new2003 = np.linspace(1,365,50)
y_new2003 = f7(x_new2003)

ax.plot(x_new2003,y_new2003,label="2003", color = "#0e2c5e")

#plot for 2004
x8 = df_2004['day_of_year']
y8 = df_2004['swell_height']
z8 = np.polyfit(x8,y8, 4)
f8 = np.poly1d(z8)


x_new2004 = np.linspace(1,365,50)
y_new2004 = f8(x_new2004)

ax.plot(x_new2004,y_new2004,label="2004", color = "#000000")

#plot for 2005
x9 = df_2005['day_of_year']
y9 = df_2005['swell_height']
z9 = np.polyfit(x9,y9, 4)
f9 = np.poly1d(z9)


x_new2005 = np.linspace(1,365,50)
y_new2005 = f9(x_new2005)

ax.plot(x_new2005,y_new2005,"--",label="2005", color = "#000000")

#plot for 2006
x10 = df_2006['day_of_year']
y10 = df_2006['swell_height']
z10 = np.polyfit(x10,y10, 4)
f10 = np.poly1d(z10)


x_new2006 = np.linspace(1,365,50)
y_new2006 = f10(x_new2006)

ax.plot(x_new2006,y_new2006,"x", label="2006", color="#000000")

ticks = [a for a in range(365) if (a-16)%30 == 0]
plt.setp(ax, xticks=ticks, xticklabels=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"], xlabel = "Month", ylabel = "Swell Height (Metres)")


plt.title("Taghazout Swell Height - Polynomial Fit", fontsize = 20)
plt.xlabel("Day of Year")
plt.ylabel("Swell Height (Metres)")
plt.grid()
plt.legend()
plt.show()


from sklearn.metrics import r2_score

coefficient_of_dermination = r2_score(y2, f2(x2))

print coefficient_of_dermination
# Out:
#             4             3             2
# -1.926e-09 x + 1.472e-06 x - 0.0003185 x + 0.01752 x + 1.768
#            4             3             2
# 2.851e-09 x - 1.993e-06 x + 0.0004794 x - 0.04773 x + 3.374
#            4             3           2
# 1.793e-11 x - 7.838e-08 x + 6.9e-05 x - 0.01788 x + 3.008
# 0.3248293757586098

# %% [markdown]
# # Imported NWW3 Source Data Opened in Panoply (Exported as PNG and Combined as GIF)

# %%
import os
import imageio

png_dir = 'Images_World'
images = []
for file_name in os.listdir(png_dir):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('gif/global_swell_height.gif', images, duration = 0.5)

# %% [markdown]
# ![SegmentLocal](gif/global_swell_height.gif "segment")
